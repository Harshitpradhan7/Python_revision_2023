# %%
import numpy as np
import pandas as pd
import seaborn as sns
# import matplotlib.pyplot as plt
import chardet
from datetime import datetime

# %%
## Code to check encodig type of a file.
with open('Museum_Visitors_20231230.csv', 'rb') as file:
    print(chardet.detect(file.read()))
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %%
df = pd.read_csv('Museum_Visitors_20231230.csv', parse_dates= ['Month'])
df.head()
# Out:
#        Month  America Tropical Interpretive Center  Avila Adobe  \
# 0 2014-01-01                                6602.0      24778.0
# 1 2014-02-01                                5029.0      18976.0
# 2 2014-03-01                                8129.0      25231.0
# 3 2014-04-01                                2824.0      26989.0
# 4 2014-05-01                               10694.0      36883.0
#
#    Chinese American Museum  Gateway to Nature Center  Firehouse Museum  \
# 0                   1581.0                       NaN            4486.0
# 1                   1785.0                       NaN            4172.0
# 2                   3229.0                       NaN            7082.0
# 3                   2129.0                       NaN            6756.0
# 4                   3676.0                       NaN           10858.0
#
#    Hellman Quon  IAMLA  Pico House   Visitor Center/ El Tranquilo Gallery  \
# 0           0.0    NaN       2204.0                                2961.0
# ...

# %%
df['Year'] = pd.to_datetime(df['Month']).dt.year
df
# Out:
#          Month  America Tropical Interpretive Center  Avila Adobe  \
# 0   2014-01-01                                6602.0      24778.0
# 1   2014-02-01                                5029.0      18976.0
# 2   2014-03-01                                8129.0      25231.0
# 3   2014-04-01                                2824.0      26989.0
# 4   2014-05-01                               10694.0      36883.0
# ..         ...                                   ...          ...
# 112 2023-05-01                                3816.0      16085.0
# 113 2023-06-01                                2227.0      13604.0
# 114 2023-07-01                                2057.0      13607.0
# 115 2023-08-01                                1470.0      11413.0
# 116 2023-09-01                                1478.0      11970.0
#
#      Chinese American Museum  Gateway to Nature Center  Firehouse Museum  \
# 0                     1581.0                       NaN            4486.0
# ...

# %%
plt.figure(figsize = (12,6))
sns.lineplot(data = df)
# Out:
# <Axes: >

# %%
plt.figure(figsize = (12,6))
sns.lineplot(data =df, x= df['Year'], y = df['Avila Adobe'])
# plt.ylabel("Number of visitors")
plt.title("Yearly Visitors to Avila Adobe")
# plt.xlabel("")
plt.ylabel("")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 6
#       4 plt.title("Yearly Visitors to Avila Adobe")
#       5 # plt.xlabel("")
# ----> 6 plt.ylabel("")
#
# TypeError: 'str' object is not callable

# %%
df.columns
# Out:
# Index(['Month', 'America Tropical Interpretive Center', 'Avila Adobe',
#        'Chinese American Museum', 'Gateway to Nature Center',
#        'Firehouse Museum', 'Hellman Quon', 'IAMLA', 'Pico House ',
#        'Visitor Center/ El Tranquilo Gallery', 'Museum of Social Justice',
#        'Biscailuz Gallery/ PK Outdoor Exhibit', 'Year'],
#       dtype='object')

# %%
sns.histplot()
