# %%
import numpy as np
import pandas as pd
import seaborn as sns
import chardet  ## Library to check encodig type of a file.

# %%
## Code to check encodig type of a file.
with open('spotify-2023.csv', 'rb') as file:
    print(chardet.detect(file.read()))
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
df = pd.read_csv('spotify-2023.csv', encoding= 'ISO-8859-1,', index_col ='track_name' )

# %%
df.head()
# Out:
#                                        artist(s)_name  artist_count  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# LALA                                      Myke Towers             1
# vampire                                Olivia Rodrigo             1
# Cruel Summer                             Taylor Swift             1
# WHERE SHE GOES                              Bad Bunny             1
#
#                                      released_year  released_month  \
# track_name
# Seven (feat. Latto) (Explicit Ver.)           2023               7
# LALA                                          2023               3
# vampire                                       2023               6
# Cruel Summer                                  2019               8
# WHERE SHE GOES                                2023               5
#
#                                      released_day  in_spotify_playlists  \
# track_name
# ...

# %%
df.columns
# Out:
# Index(['artist(s)_name', 'artist_count', 'released_year', 'released_month',
#        'released_day', 'in_spotify_playlists', 'in_spotify_charts', 'streams',
#        'in_apple_playlists', 'in_apple_charts', 'in_deezer_playlists',
#        'in_deezer_charts', 'in_shazam_charts', 'bpm', 'key', 'mode',
#        'danceability_%', 'valence_%', 'energy_%', 'acousticness_%',
#        'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
sns.lineplot()

# %%
sns.hist(x = df['artist(s)_name'].head(), y=df['streams'].head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 sns.hist(x = df['artist(s)_name'].head(), y=df['streams'].head())
#
# AttributeError: module 'seaborn' has no attribute 'hist'
